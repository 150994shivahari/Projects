# %% [markdown]
# ## House Price Prediction Using Pytorch

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./houseprice.csv',usecols=["SalePrice", "MSSubClass", "MSZoning", "LotFrontage", "LotArea",
                                         "Street", "YearBuilt", "LotShape", "1stFlrSF", "2ndFlrSF"]).dropna()

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  YearBuilt  \
# 0          60       RL         65.0     8450   Pave      Reg       2003
# 1          20       RL         80.0     9600   Pave      Reg       1976
# 2          60       RL         68.0    11250   Pave      IR1       2001
# 3          70       RL         60.0     9550   Pave      IR1       1915
# 4          60       RL         84.0    14260   Pave      IR1       2000
#
#    1stFlrSF  2ndFlrSF  SalePrice
# 0       856       854     208500
# 1      1262         0     181500
# 2       920       866     223500
# 3       961       756     140000
# 4      1145      1053     250000

# %%
df.shape
# Out:
# (1201, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1459
# Data columns (total 10 columns):
# MSSubClass     1201 non-null int64
# MSZoning       1201 non-null object
# LotFrontage    1201 non-null float64
# LotArea        1201 non-null int64
# Street         1201 non-null object
# LotShape       1201 non-null object
# YearBuilt      1201 non-null int64
# 1stFlrSF       1201 non-null int64
# 2ndFlrSF       1201 non-null int64
# SalePrice      1201 non-null int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 103.2+ KB

# %%
for i in df.columns:
    print("Column name {} and unique values are {}".format(i,len(df[i].unique())))
# Out:
# Column name MSSubClass and unique values are 15
# Column name MSZoning and unique values are 5
# Column name LotFrontage and unique values are 110
# Column name LotArea and unique values are 869
# Column name Street and unique values are 2
# Column name LotShape and unique values are 4
# Column name YearBuilt and unique values are 112
# Column name 1stFlrSF and unique values are 678
# Column name 2ndFlrSF and unique values are 368
# Column name SalePrice and unique values are 597

# %%
import datetime
datetime.datetime.now().year
# Out:
# 2020

# %%
df['Total Years']=datetime.datetime.now().year-df['YearBuilt']

# %%
df.drop("YearBuilt",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', '1stFlrSF', '2ndFlrSF', 'SalePrice', 'Total Years'],
#       dtype='object')

# %%
cat_features=["MSSubClass", "MSZoning", "Street", "LotShape"]
out_feature="SalePrice"

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoders={}
lbl_encoders["MSSubClass"]=LabelEncoder()
lbl_encoders["MSSubClass"].fit_transform(df["MSSubClass"])
# Out:
# array([5, 0, 5, ..., 6, 0, 0], dtype=int64)

# %%
lbl_encoders
# Out:
# {'MSSubClass': LabelEncoder()}

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoders={}
for feature in cat_features:
    lbl_encoders[feature]=LabelEncoder()
    df[feature]=lbl_encoders[feature].fit_transform(df[feature])

# %%
df.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  1stFlrSF  \
# 0           5         3         65.0     8450       1         3       856
# 1           0         3         80.0     9600       1         3      1262
# 2           5         3         68.0    11250       1         0       920
# 3           6         3         60.0     9550       1         0       961
# 4           5         3         84.0    14260       1         0      1145
#
#    2ndFlrSF  SalePrice  Total Years
# 0       854     208500           17
# 1         0     181500           44
# 2       866     223500           19
# 3       756     140000          105
# 4      1053     250000           20

# %%
### Stacking and Converting Into Tensors
cat_features=np.stack([df['MSSubClass'],df['MSZoning'],df['Street'],df['LotShape']],1)
cat_features
# Out:
# array([[5, 3, 1, 3],
#        [0, 3, 1, 3],
#        [5, 3, 1, 0],
#        ...,
#        [6, 3, 1, 3],
#        [0, 3, 1, 3],
#        [0, 3, 1, 3]], dtype=int64)

# %%
### Convert numpy to Tensors
import torch
cat_features=torch.tensor(cat_features,dtype=torch.int64)
cat_features
# Out:
# tensor([[5, 3, 1, 3],
#         [0, 3, 1, 3],
#         [5, 3, 1, 0],
#         ...,
#         [6, 3, 1, 3],
#         [0, 3, 1, 3],
#         [0, 3, 1, 3]])

# %%
#### create continuous variable
cont_features=[]
for i in df.columns:
    if i in ["MSSubClass", "MSZoning", "Street", "LotShape","SalePrice"]:
        pass
    else:
        cont_features.append(i)

# %%
cont_features
# Out:
# ['LotFrontage', 'LotArea', '1stFlrSF', '2ndFlrSF', 'Total Years']

# %%
### Stacking continuous variable to a tensor
cont_values=np.stack([df[i].values for i in cont_features],axis=1)
cont_values=torch.tensor(cont_values,dtype=torch.float)
cont_values
# Out:
# tensor([[   65.,  8450.,   856.,   854.,    17.],
#         [   80.,  9600.,  1262.,     0.,    44.],
#         [   68., 11250.,   920.,   866.,    19.],
#         ...,
#         [   66.,  9042.,  1188.,  1152.,    79.],
#         [   68.,  9717.,  1078.,     0.,    70.],
#         [   75.,  9937.,  1256.,     0.,    55.]])

# %%
cont_values.dtype
# Out:
# torch.float32

# %%
### Dependent Feature 
y=torch.tensor(df['SalePrice'].values,dtype=torch.float).reshape(-1,1)
y
# Out:
# tensor([[208500.],
#         [181500.],
#         [223500.],
#         ...,
#         [266500.],
#         [142125.],
#         [147500.]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1459
# Data columns (total 10 columns):
# MSSubClass     1201 non-null int64
# MSZoning       1201 non-null int32
# LotFrontage    1201 non-null float64
# LotArea        1201 non-null int64
# Street         1201 non-null int32
# LotShape       1201 non-null int32
# 1stFlrSF       1201 non-null int64
# 2ndFlrSF       1201 non-null int64
# SalePrice      1201 non-null int64
# Total Years    1201 non-null int64
# dtypes: float64(1), int32(3), int64(6)
# memory usage: 89.1 KB

# %%
cat_features.shape,cont_values.shape,y.shape
# Out:
# (torch.Size([1201, 4]), torch.Size([1201, 5]), torch.Size([1201, 1]))

# %%
len(df['MSSubClass'].unique())
# Out:
# 15

# %%
#### Embedding Size For Categorical columns
cat_dims=[len(df[col].unique()) for col in ["MSSubClass", "MSZoning", "Street", "LotShape"]]

# %%
cat_dims
# Out:
# [15, 5, 2, 4]

# %%
embedding_dim= [(x, min(50, (x + 1) // 2)) for x in cat_dims]

# %%
embedding_dim
# Out:
# [(15, 8), (5, 3), (2, 1), (4, 2)]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
embed_representation=nn.ModuleList([nn.Embedding(inp,out) for inp,out in embedding_dim])
embed_representation
# Out:
# ModuleList(
#   (0): Embedding(15, 8)
#   (1): Embedding(5, 3)
#   (2): Embedding(2, 1)
#   (3): Embedding(4, 2)
# )

# %%
cat_features
# Out:
# tensor([[5, 3, 1, 3],
#         [0, 3, 1, 3],
#         [5, 3, 1, 0],
#         ...,
#         [6, 3, 1, 3],
#         [0, 3, 1, 3],
#         [0, 3, 1, 3]])

# %%
cat_featuresz=cat_features[:4]
cat_featuresz
# Out:
# tensor([[5, 3, 1, 3],
#         [0, 3, 1, 3],
#         [5, 3, 1, 0],
#         [6, 3, 1, 0]])

# %%
pd.set_option('display.max_rows', 500)
embedding_val=[]
for i,e in enumerate(embed_representation):
    embedding_val.append(e(cat_features[:,i]))

# %%
embedding_val
# Out:
# [tensor([[-0.0192,  0.2156,  0.0783,  ..., -1.7073, -0.1094, -0.8735],
#          [ 0.8725,  1.6844,  1.6478,  ..., -0.6130, -0.4029,  1.1516],
#          [-0.0192,  0.2156,  0.0783,  ..., -1.7073, -0.1094, -0.8735],
#          ...,
#          [ 0.3033, -1.8885,  2.0891,  ..., -2.2290, -1.4483, -0.2902],
#          [ 0.8725,  1.6844,  1.6478,  ..., -0.6130, -0.4029,  1.1516],
#          [ 0.8725,  1.6844,  1.6478,  ..., -0.6130, -0.4029,  1.1516]],
#         grad_fn=<EmbeddingBackward>), tensor([[ 0.3318, -0.0883, -0.5150],
#          [ 0.3318, -0.0883, -0.5150],
#          [ 0.3318, -0.0883, -0.5150],
#          ...,
#          [ 0.3318, -0.0883, -0.5150],
#          [ 0.3318, -0.0883, -0.5150],
#          [ 0.3318, -0.0883, -0.5150]], grad_fn=<EmbeddingBackward>), tensor([[1.0299],
#          [1.0299],
#          [1.0299],
#          ...,
#          [1.0299],
#          [1.0299],
#          [1.0299]], grad_fn=<EmbeddingBackward>), tensor([[ 1.1506, -0.1699],
#          [ 1.1506, -0.1699],
#          [ 0.8582,  0.4397],
#          ...,
#          [ 1.1506, -0.1699],
#          [ 1.1506, -0.1699],
#          [ 1.1506, -0.1699]], grad_fn=<EmbeddingBackward>)]

# %%
z = torch.cat(embedding_val, 1)
z
# Out:
# tensor([[-0.0192,  0.2156,  0.0783,  ...,  1.0299,  1.1506, -0.1699],
#         [ 0.8725,  1.6844,  1.6478,  ...,  1.0299,  1.1506, -0.1699],
#         [-0.0192,  0.2156,  0.0783,  ...,  1.0299,  0.8582,  0.4397],
#         ...,
#         [ 0.3033, -1.8885,  2.0891,  ...,  1.0299,  1.1506, -0.1699],
#         [ 0.8725,  1.6844,  1.6478,  ...,  1.0299,  1.1506, -0.1699],
#         [ 0.8725,  1.6844,  1.6478,  ...,  1.0299,  1.1506, -0.1699]],
#        grad_fn=<CatBackward>)

# %%
#### Implement dropupout
droput=nn.Dropout(.4)

# %%
final_embed=droput(z)
final_embed
# Out:
# tensor([[-0.0000,  0.3593,  0.0000,  ...,  0.0000,  1.9177, -0.2832],
#         [ 1.4542,  2.8073,  0.0000,  ...,  0.0000,  1.9177, -0.2832],
#         [-0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.7329],
#         ...,
#         [ 0.5055, -0.0000,  3.4819,  ...,  0.0000,  0.0000, -0.2832],
#         [ 1.4542,  2.8073,  2.7464,  ...,  0.0000,  0.0000, -0.2832],
#         [ 0.0000,  0.0000,  2.7464,  ...,  1.7164,  1.9177, -0.2832]],
#        grad_fn=<DropoutBackward>)

# %%
##### Create a Feed Forward Neural Network
import torch
import torch.nn as nn
import torch.nn.functional as F
class FeedForwardNN(nn.Module):

    def __init__(self, embedding_dim, n_cont, out_sz, layers, p=0.5):
        super().__init__()
        self.embeds = nn.ModuleList([nn.Embedding(inp,out) for inp,out in embedding_dim])
        self.emb_drop = nn.Dropout(p)
        self.bn_cont = nn.BatchNorm1d(n_cont)
        
        layerlist = []
        n_emb = sum((out for inp,out in embedding_dim))
        n_in = n_emb + n_cont
        
        for i in layers:
            layerlist.append(nn.Linear(n_in,i)) 
            layerlist.append(nn.ReLU(inplace=True))
            layerlist.append(nn.BatchNorm1d(i))
            layerlist.append(nn.Dropout(p))
            n_in = i
        layerlist.append(nn.Linear(layers[-1],out_sz))
            
        self.layers = nn.Sequential(*layerlist)
    
    def forward(self, x_cat, x_cont):
        embeddings = []
        for i,e in enumerate(self.embeds):
            embeddings.append(e(x_cat[:,i]))
        x = torch.cat(embeddings, 1)
        x = self.emb_drop(x)
        
        x_cont = self.bn_cont(x_cont)
        x = torch.cat([x, x_cont], 1)
        x = self.layers(x)
        return x

# %%
len(cont_features)
# Out:
# 5

# %%
torch.manual_seed(100)
model=FeedForwardNN(embedding_dim,len(cont_features),1,[100,50],p=0.4)

# %%
model
# Out:
# FeedForwardNN(
#   (embeds): ModuleList(
#     (0): Embedding(15, 8)
#     (1): Embedding(5, 3)
#     (2): Embedding(2, 1)
#     (3): Embedding(4, 2)
#   )
#   (emb_drop): Dropout(p=0.4)
#   (bn_cont): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=19, out_features=100, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.4)
#     (4): Linear(in_features=100, out_features=50, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.4)
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Define Loss and Optimization:

# %%
loss_function=nn.MSELoss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.01)

# %%
df.shape
# Out:
# (1201, 10)

# %%
cont_values
# Out:
# tensor([[   65.,  8450.,   856.,   854.,    17.],
#         [   80.,  9600.,  1262.,     0.,    44.],
#         [   68., 11250.,   920.,   866.,    19.],
#         ...,
#         [   66.,  9042.,  1188.,  1152.,    79.],
#         [   68.,  9717.,  1078.,     0.,    70.],
#         [   75.,  9937.,  1256.,     0.,    55.]])

# %%
cont_values.shape
# Out:
# torch.Size([1201, 5])

# %%
batch_size=1200
test_size=int(batch_size*0.15)
train_categorical=cat_features[:batch_size-test_size]
test_categorical=cat_features[batch_size-test_size:batch_size]
train_cont=cont_values[:batch_size-test_size]
test_cont=cont_values[batch_size-test_size:batch_size]
y_train=y[:batch_size-test_size]
y_test=y[batch_size-test_size:batch_size]

# %%
len(train_categorical),len(test_categorical),len(train_cont),len(test_cont),len(y_train),len(y_test)
# Out:
# (1020, 180, 1020, 180, 1020, 180)

# %%
epochs=5000
final_losses=[]
for i in range(epochs):
    i=i+1
    y_pred=model(train_categorical,train_cont)
    loss=torch.sqrt(loss_function(y_pred,y_train)) ### RMSE
    final_losses.append(loss)
    if i%10==1:
        print("Epoch number: {} and the loss : {}".format(i,loss.item()))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epo
# Epoch number: 4731 and the loss : 37185.39453125
# Epoch number: 4741 and the loss : 35024.12890625
# Epoch number: 4751 and the loss : 35794.44921875
# Epoch number: 4761 and the loss : 37532.25390625
# Epoch number: 4771 and the loss : 35844.109375
# Epoch number: 4781 and the loss : 36199.81640625
# Epoch number: 4791 and the loss : 35068.94921875
# Epoch number: 4801 and the loss : 34485.8671875
# Epoch number: 4811 and the loss : 35362.6640625
# Epoch number: 4821 and the loss : 33740.3671875
# Epoch number: 4831 and the loss : 35309.203125
# Epoch number: 4841 and the loss : 35580.03125
# Epoch number: 4851 and the loss : 34655.6171875
# Epoch number: 4861 and the loss : 34857.140625
# Epoch number: 4871 and the loss : 36136.4453125
# Epoch number: 4881 and the loss : 35667.16796875
# Epoch number: 4891 and the loss : 33568.4453125
# Epoch number: 4901 and the loss : 33957.99609375
# Epoch number: 4911 and the loss : 36727.51171875
# Epoch number: 4921 and the loss : 34742.921875
# Epoch number: 4931 and the loss : 36160.47265625
# Epoch number: 4941 and the loss : 33423.44921875
# Epoch number: 4951 and the loss : 35043.06640625
# Epoch number: 4961 and the loss : 34979.18359375
# Epoch number: 4971 and the loss : 35172.2265625
# Epoch number: 4981 and the loss : 36353.47265625
# Epoch number: 4991 and the loss : 35214.171875

# %%
#### Validate the Test Data
y_pred=""
with torch.no_grad():
    y_pred=model(test_categorical,test_cont)
    loss=torch.sqrt(loss_function(y_pred,y_test))
print('RMSE: {}'.format(loss))
# Out:
# RMSE: 41801.68359375

# %%
data_verify=pd.DataFrame(y_test.tolist(),columns=["Test"])

# %%
data_predicted=pd.DataFrame(y_pred.tolist(),columns=["Prediction"])

# %%
data_predicted
# Out:
#         Prediction
# 0    163325.406250
# 1    179278.250000
# 2    161876.312500
# 3    188466.750000
# 4    147170.828125
# 5    179108.187500
# 6    235840.062500
# 7    295837.687500
# 8    151762.109375
# 9    429709.343750
# 10   242881.625000
# 11   181377.187500
# 12   180347.562500
# 13   149270.718750
# 14   279990.593750
# 15    85252.906250
# 16   201432.343750
# 17   129562.531250
# 18   269043.218750
# 19    82871.125000
# 20   133785.593750
# 21   134816.468750
# 22   112047.953125
# 23   196361.484375
# 24   207352.812500
# 25   190465.937500
# 26   127514.890625
# 27   359025.750000
# 28   122660.710938
# 29   114742.148438
# 30    81563.539062
# 31   139846.546875
# 32   293528.437500
# 33    48399.699219
# 34   225970.156250
# 35   131860.187500
# 36   133115.437500
# 37   117055.046875
# 38   190985.250000
# 39   132490.203125
# 40   220313.281250
# 41   231384.593750
# 42   108317.835938
# 43   121260.343750
# 44   186483.250000
# 45    95218.929688
# 46   122464.507812
# 47   107490.070312
# 48   147760.250000
# 49   355329.687500
# 50   136413.312500
# 51   254361.500000
# 52   227458.703125
# 53   136372.500000
# 54   265860.500000
# 55   215603.500000
# 56   121063.203125
# 57   130677.335938
# 58   200653.000000
# 59   143235.906250
# 60   335232.062500
# 61   130584.093750
# 62   242390.406250
# 63   216009.187500
# 64   245992.812500
# 65   111750.656250
# 66   119814.156250
# 67   250107.234375
# 68    93749.406250
# 69   294017.937500
# 70    92943.296875
# 71    94723.734375
# 72    96391.609375
# 73   230872.781250
# 74   195970.687500
# 75   271572.062500
# 76   165995.531250
# 77   115017.640625
# 78   139009.671875
# 79   125899.500000
# 80   159765.781250
# 81   143474.000000
# 82    60532.542969
# 83   218020.218750
# 84   152097.875000
# 85   136109.546875
# 86   206916.953125
# 87   163591.390625
# 88   151900.281250
# 89    85348.281250
# 90   324051.625000
# 91   144997.046875
# 92   175553.171875
# 93   178813.656250
# 94    82083.125000
# 95   334780.156250
# 96   224610.718750
# 97   288243.718750
# 98   258460.812500
# 99   184842.593750
# 100  206230.265625
# 101  129533.085938
# 102  237185.062500
# 103  110507.125000
# 104  212443.812500
# 105   99827.781250
# 106  142422.921875
# 107  257903.718750
# 108  313040.562500
# 109  289907.562500
# 110   79863.609375
# 111  133713.375000
# 112   76567.140625
# 113  197918.218750
# 114   48291.441406
# 115  131336.000000
# 116   99375.015625
# 117   84759.906250
# 118  344961.343750
# 119  162653.187500
# 120  221714.671875
# 121  128671.812500
# 122  194861.937500
# 123  139199.125000
# 124   85243.414062
# 125  141959.562500
# 126  254904.093750
# 127  279141.750000
# 128  118190.500000
# 129  197650.281250
# 130  129543.671875
# 131  100080.359375
# 132  194121.406250
# 133  153639.375000
# 134  210714.812500
# 135  101287.421875
# 136  266890.250000
# 137  112936.312500
# 138  126500.515625
# 139  274702.187500
# 140  252277.656250
# 141  140570.281250
# 142   95031.750000
# 143  333480.375000
# 144  174224.703125
# 145  232077.359375
# 146  105415.312500
# 147  159651.546875
# 148  142905.875000
# 149  157344.500000
# 150  141666.906250
# 151  148672.031250
# 152  243691.843750
# 153  142421.906250
# 154   98742.656250
# 155  286411.687500
# 156  101331.375000
# 157  191640.812500
# 158  168796.343750
# 159  166719.328125
# 160  107348.789062
# 161  392664.500000
# 162  141975.031250
# 163  204736.328125
# 164  230507.203125
# 165  313403.406250
# 166  191061.953125
# 167  126042.546875
# 168  235049.406250
# 169   96792.148438
# 170   61249.578125
# 171  148185.328125
# 172  258241.531250
# 173   95388.890625
# 174  193952.500000
# 175  159340.203125
# 176  177704.312500
# 177  259126.281250
# 178  250070.109375
# 179  124608.453125

# %%
final_output=pd.concat([data_verify,data_predicted],axis=1)
final_output['Difference']=final_output['Test']-final_output['Prediction']
final_output.head()
# Out:
#        Test     Prediction    Difference
# 0  130000.0  163325.406250 -33325.406250
# 1  138887.0  179278.250000 -40391.250000
# 2  175500.0  161876.312500  13623.687500
# 3  195000.0  188466.750000   6533.250000
# 4  142500.0  147170.828125  -4670.828125

# %%
#### Saving The Model
#### Save the model
torch.save(model,'HousePrice.pt')
# Out:
# C:\Users\venka\Anaconda3\lib\site-packages\torch\serialization.py:241: UserWarning: Couldn't retrieve source code for container of type FeedForwardNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
torch.save(model.state_dict(),'HouseWeights.pt')

# %%
### Loading the saved Model
embs_size=[(15, 8), (5, 3), (2, 1), (4, 2)]
model1=FeedForwardNN(embs_size,5,1,[100,50],p=0.4)

# %%
model1.load_state_dict(torch.load('HouseWeights.pt'))

# %%
model1.eval()
# Out:
# FeedForwardNN(
#   (embeds): ModuleList(
#     (0): Embedding(15, 8)
#     (1): Embedding(5, 3)
#     (2): Embedding(2, 1)
#     (3): Embedding(4, 2)
#   )
#   (emb_drop): Dropout(p=0.4)
#   (bn_cont): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=19, out_features=100, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.4)
#     (4): Linear(in_features=100, out_features=50, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.4)
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
